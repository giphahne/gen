# %%
from utils.utils import *

# %%
a = "ABABABABCABABABA"
b = "BAABABACBABBB"

# %%
c = longest_common_substr(a, b)
c
# Out:
# A: ABABABABCABABABA
# len(A): 16
# B: BAABABACBABBB
# len(B): 13
# (i,j): (0, 0)
# (i,j): (0, 1)
# (i,j): (0, 2)
# (i,j): (0, 3)
# (i,j): (0, 4)
# (i,j): (0, 5)
# (i,j): (0, 6)
# (i,j): (0, 7)
# (i,j): (0, 8)
# (i,j): (0, 9)
# (i,j): (0, 10)
# (i,j): (0, 11)
# (i,j): (0, 12)
# (i,j): (1, 0)
# (i,j): (1, 1)
# (i,j): (1, 2)
# (i,j): (1, 3)
# (i,j): (1, 4)
# (i,j): (1, 5)
# (i,j): (1, 6)
# (i,j): (1, 7)
# (i,j): (1, 8)
# (i,j): (1, 9)
# (i,j): (1, 10)
# (i,j): (1, 11)
# (i,j): (1, 12)
# (i,j): (2, 0)
# (i,j): (2, 1)
# (i,j): (2, 2)
# (i,j): (2, 3)
# (i,j): (2, 4)
# (i,j): (2, 5)
# (i,j): (2, 6)
# (i,j): (2, 7)
# (i,j): (2, 8)
# (i,j): (2, 9)
# (i,j): (2, 10)
# (i,j): (2, 11)
# (i,j): (2, 12)
# (i,j): (3, 0)
# (i,j): (3, 1)
# (i,j): (3, 2)
# (i,j): (3, 3)
# (i,j): (3, 4)
# (i,j): (3, 5)
# (i,j): (3, 6)
# (i,j): (3, 7)
# (i,j): (3, 8)
# (i,j): (3, 9)
# (i,j): (3, 10)
# (i,j): (3, 11)
# (i,j): (3, 12)
# (i,j): (4, 0)
# (i,j): (4, 1)
# (i,j): (4, 2)
# (i,j): (4, 3)
# (i,j): (4, 4)
# ...
